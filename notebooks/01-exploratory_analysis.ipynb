# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os 
if 'notebooks' in os.getcwd():
    os.chdir('..')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exploratory data Analysis (EDA)

# %%
X_train = pd.read_csv("data/X_train_YG7NZSq.csv", index_col=0)
X_train.columns.name = 'date'
X_train.head()
# Out:
# date             0         1         2         3         4         5  \
# stocksID
# 0        -0.018647 -0.013002 -0.010776 -0.016676 -0.005110  0.009092
# 1        -0.008254 -0.022280  0.012173 -0.006820 -0.004055  0.012912
# 2        -0.008404 -0.013629 -0.006044 -0.003425 -0.009522 -0.001353
# 3        -0.022734 -0.006981 -0.008568 -0.010899 -0.017981  0.002485
# 4        -0.024546 -0.008315 -0.007991 -0.003515  0.007872  0.007082
#
# date             6         7         8         9  ...       744       745  \
# stocksID                                          ...
# 0        -0.011745  0.007120 -0.008451  0.009119  ... -0.012525 -0.011716
# 1        -0.001293  0.009994 -0.002747  0.001664  ...  0.014432 -0.002255
# 2        -0.000637  0.007640  0.001600  0.007416  ... -0.006245 -0.001329
# 3        -0.011980  0.012446 -0.010636  0.003807  ... -0.005179 -0.003442
# 4        -0.004614 -0.008182 -0.005255  0.014404  ... -0.017507 -0.001233
#
# ...

# %%
X_train.shape
# Out:
# (50, 755)

# %%
y_train = pd.read_csv("data/Y_train_wz11VM6.csv")
y_train.head()
# Out:
#    stocksID       250       251       252       253       254       255  \
# 0         0  0.001128 -0.001046 -0.007027 -0.009757 -0.005868 -0.008563
# 1         1 -0.003274 -0.001070  0.000205  0.004862 -0.012834 -0.004868
# 2         2 -0.003446 -0.001272  0.005824 -0.006994 -0.005512 -0.003652
# 3         3  0.001727  0.003143 -0.003606 -0.022219 -0.017467 -0.004536
# 4         4  0.004907  0.002472 -0.001487  0.003317 -0.006636 -0.012548
#
#         256       257       258  ...       744       745       746       747  \
# 0 -0.005857 -0.004588 -0.000240  ... -0.012525 -0.011716  0.003532  0.009965
# 1  0.005476 -0.009097  0.000284  ...  0.014432 -0.002255 -0.011493  0.002291
# 2  0.003997 -0.005139 -0.004550  ... -0.006245 -0.001329  0.005230  0.003510
# 3 -0.003512 -0.000156  0.005489  ... -0.005179 -0.003442  0.002733  0.013369
# 4 -0.000942 -0.009569  0.004660  ... -0.017507 -0.001233 -0.000552  0.004664
#
#         748       749       750       751       752       753
# ...

# %%
(X_train['250'] == y_train['250']).all()
# Out:
# True

# %%
X_train.T
# Out:
# stocksID        0         1         2         3         4         5   \
# date
# 0        -0.018647 -0.008254 -0.008404 -0.022734 -0.024546 -0.019243
# 1        -0.013002 -0.022280 -0.013629 -0.006981 -0.008315 -0.004789
# 2        -0.010776  0.012173 -0.006044 -0.008568 -0.007991 -0.004691
# 3        -0.016676 -0.006820 -0.003425 -0.010899 -0.003515  0.002805
# 4        -0.005110 -0.004055 -0.009522 -0.017981  0.007872 -0.006069
# ...            ...       ...       ...       ...       ...       ...
# 749      -0.001236 -0.004026 -0.000343  0.001201  0.007695  0.007474
# 750      -0.002732 -0.004672  0.001757 -0.003669  0.003775 -0.002425
# 751       0.013074 -0.002889  0.004972  0.008690  0.005097  0.003741
# 752      -0.005843 -0.004984  0.004916  0.000272  0.001135  0.006103
# 753      -0.003823  0.005005 -0.007338 -0.008150 -0.009262 -0.004848
#
# stocksID        6         7         8         9   ...        40        41  \
# date                                              ...
# ...

# %%
X_train.T.cumsum().plot(legend=False)
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## Submission example

# %%
submission_example_df= pd.read_csv(
    'data/submissionExample_5hCwVFq.csv',
    index_col=0
)
submission_example_df
# Out:
#              0
# 0    -0.031776
# 1     0.078577
# 2    -0.097612
# 3     0.027429
# 4     0.037441
# ...        ...
# 2505  0.788012
# 2506  0.713994
# 2507  0.607577
# 2508  0.124029
# 2509  0.140057
#
# [2510 rows x 1 columns]
